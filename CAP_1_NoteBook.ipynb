# %% [markdown]
# **Hello, World!** This is the template NoteBook for the Github and for the first week of the Capstone Course week 1. And this notebook will be mainly used for the capstone project.

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
